# %%
import requests
import pandas as pd

# %%
from datetime import datetime, timedelta
# Out:
# '2023-09-28'

# %%
def get_chemrxiv(days_back):
    skip_num = 0
    total_count=1
    start_date = (datetime.now()-timedelta(days=days_back)).strftime('%Y-%m-%d')
    def get_affiliation(x):
        out = []
        for affil in x:
            out.append(affil['name'])
        return out
    def get_authors_affils(x):
        authors = []
        affiliations = []
        for name in x:
            authors.append(name['firstName']+' '+name['lastName'])
            affiliations.extend(get_affiliation(name['institutions']))
        return authors, list(set(affiliations))
    def get_chemrixiv_subjects(x):
        subjects = []
        for subj in x:
            subjects.append(subj['name'])
        return subjects
    out = []
    while skip_num < total_count:
        response = requests.get(f'https://chemrxiv.org/engage/chemrxiv/public-api/v1/items?limit=50&skip={skip_num}&searchDateFrom={start_date}T00:00:00.000Z')
        json_resp = response.json()
        total_count = json_resp['totalCount']
        skip_num+=len(json_resp['itemHits'])
        print(skip_num)
        for paper in json_resp['itemHits']:
            paper_info = {}
            paper_info['paper_id'] = paper['item']['id']
            paper_info['authors'],paper_info['affiliations'] = get_authors_affils(x = paper['item']['authors'])
            paper_info['subjects'] = get_chemrixiv_subjects(paper['item']['categories'])
            paper_info['title'] = paper['item']['title']
            paper_info['abstract'] = paper['item']['abstract']
            paper_info['url'] = 'https://chemrxiv.org/engage/chemrxiv/article-details/'+str(paper['item']['id'])
            paper_info['date'] = paper['item']['publishedDate'][:10]
            paper_info['source'] = paper['item']['origin']
            out.append(paper_info)
    return pd.DataFrame.from_records(out)

# %%
get_chemrxiv(3)
# Out:
# 50
# 76
#                     paper_id  \
# 0   6516c4f8a69febde9eeb8ad2
# 1   65168004ade1178b24567cd3
# 2   6516843fade1178b2456a2f2
# 3   6516778ea69febde9ee728ef
# 4   65161cfa0065940912145855
# ..                       ...
# 71  6512b162ade1178b2424c325
# 72  65127c57ade1178b24220d4e
# 73  65127c3eade1178b24220b5d
# 74  65130f76ade1178b2429cd68
# 75  6512de440065940912ea1aa6
#
#                                               authors  \
# 0   [Piermarco Saraceno, Vladislav Sláma, Lorenzo ...
# 1   [Rıza Özçelik, Sarah de Ruiter, Francesca Gris...
# 2   [Diana Lamaa, Catherine  Cailleau, Juliette Ve...
# 3   [Javed Y.  Shaikh, Anindita  Bhowmick, Abhijit...
# 4   [Haoxin Ye, Xinzhe  Zheng, Haoming  Yang, Matt...
# ..                                                ...
# 71                                       [julio coll]
# 72  [Yu Takatani, Yuto Ohata, Takato Inoue, Naoki ...
# 73  [Michael Y. Toriyama, Cheng-Wei Lee, G. Jeffre...
# 74  [Raul  Ortega Ochoa, Bardi  Benediktsson, Rena...
# 75  [Insa Klemt, Viktor Reshetnikov, Subrata Dutta...
#
#                                          affiliations  \
# 0   [Dipartimento di Chimica e Chimica Industriale...
# 1   [Centre for Living Technologies, Alliance TU/e...
# 2   [Institut de Chimie des Substances Naturelles,...
# 3   [Indian Institute of Science Education and Res...
# 4   [University of British Columbia, University of...
# ..                                                ...
# 71                                             [CSIC]
# 72  [Laboratory of Chemical Ecology, Department of...
# 73  [Colorado School of Mines, Northwestern Univer...
# 74                  [Technical University of Denmark]
# 75  [Danylo Halytsky Lviv National Medical Univers...
#
#                                              subjects  \
# 0   [Theoretical and Computational Chemistry, Phys...
# 1   [Theoretical and Computational Chemistry, Biol...
# 2   [Biological and Medicinal Chemistry, Nanoscience]
# 3   [Organic Chemistry, Catalysis, Homogeneous Cat...
# 4   [Analytical Chemistry, Nanoscience, Agricultur...
# ..                                                ...
# 71  [Biological and Medicinal Chemistry, Bioinform...
# 72  [Organic Chemistry, Analytical Chemistry, Agri...
# 73  [Theoretical and Computational Chemistry, Mate...
# 74  [Theoretical and Computational Chemistry, Phys...
# 75  [Biological and Medicinal Chemistry, Organic C...
#
#                                                 title  \
# 0   First-principles simulation of excitation ener...
# 1   Structured State-Space Sequence Models for De ...
# 2   Overcoming Solubility Challenges: Liposomal is...
# 3   Palladium Catalyzed C3-(sp2)-H Alkenylation of...
# 4   Rapid Detection of Micro/Nanoplastics Via Inte...
# ..                                                ...
# 71        Exploring non-toxic co-evolutionary docking
# 72  Identification of (+)-7R-Actinidine and its Bi...
# 73  Defect Chemistry and Doping of Lead Phosphate ...
# 74  Materials Funnel 2.0 - Data-driven hierarchica...
# 75  A prodrug activated by H2O2 and mitochondrial ...
#
#                                              abstract  \
# 0   Abstract \tThe dynamics of delocalized exciton...
# 1   De novo drug design has witnessed remarkable p...
# 2   This study evaluated the potential of isoCoQ-C...
# 3   A Pd (II)-catalyzed direct C3-(sp2)-H alkenyla...
# 4   The fact that there is an accumulation of micr...
# ..                                                ...
# 71  Drug-spaces of nine crystallographic protein /...
# 72  Actinidine, a terpene alkaloid, is commonly fo...
# 73  Lead phosphate oxo apatite Pb10(PO4)6O is clai...
# 74  Innovating ways to explore the materials phase...
# 75  Many known chemotherapeutic anticancer agents ...
#
#                                                   url        date    source
# 0   https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-29  CHEMRXIV
# 1   https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-29  CHEMRXIV
# 2   https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-29  CHEMRXIV
# 3   https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-29  CHEMRXIV
# 4   https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-29  CHEMRXIV
# ..                                                ...         ...       ...
# 71  https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-27  CHEMRXIV
# 72  https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-27  CHEMRXIV
# 73  https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-27  CHEMRXIV
# 74  https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-27  CHEMRXIV
# 75  https://chemrxiv.org/engage/chemrxiv/article-d...  2023-09-27  CHEMRXIV
#
# [76 rows x 9 columns]

# %% [markdown]
# ### This is a test for Scopus data pull

# %%
df_explored = pd.read_pickle('last_month_wo_llama.pkl')
explored_files = df_explored[df_explored['score_divider'] <=2]['paper_id'].values.tolist()#if a paper is for some reason updated then catch it otherwise ignore as we have already indexed it
explored_files = dict(zip(explored_files, [None]*len(explored_files)))

# %%
from pybliometrics.scopus import AbstractRetrieval
def get_data_per_doi(doi, output_dict):
    ab = AbstractRetrieval(doi, view='FULL')
    output_dict['title'] = ab.title
    abstract = ab.abstract
    if not abstract:
        abstract = ab.description
    output_dict['abstract'] =abstract
    output_dict['url']= ab.scopus_link
    subjects =[]
    for area in ab.subject_areas:
        subjects.append(area.area)
    authors = []
    affiliations = []
    for author in ab.authors:
        authors.append(author.indexed_name)
    affiliations = []
    for affiliation in ab.affiliation:
        affiliations.append(affiliation.name)
    output_dict['affiliations'] = affiliations
    output_dict['authors'] = authors
    output_dict['subjects'] = subjects
    return output_dict
def get_scopus(days_back):
    api_key = 'f7401115c3b98c2edae8c1203c2f15b4'
    url = 'https://api.elsevier.com/content/search/scopus'

    # Define the query parameters
    params = {
        'apiKey':api_key,
        'query': f'LANGUAGE(english) AND AFFILCOUNTRY(United States) AND (AFFILORG(Georgia) OR AFFILORG(Emory)) AND date={str(datetime.today().year)}',
        'count': 100,  # You can adjust the number of results per page as needed
    }
    out =[]
    dates_back_found = True
    while dates_back_found:
        response = requests.get(url, params=params)
        response_json = response.json()['search-results']['entry']
        print('scopus::::::')
        print(len(response_json))
        for i in range(len(response_json)):
            paper_dict = {}
            paper_dict['paper_id'] = response_json[i]['dc:identifier']
            if paper_dict['paper_id'] in explored_files:
                print('passing:  '+str(paper_dict['paper_id']))
                continue
            paper_dict['date'] = response_json[i]['prism:coverDate']
            paper_dict = get_data_per_doi(response_json[i]['prism:doi'], paper_dict)
            out.append(paper_dict)
            if datetime.strptime(response_json[i]['prism:coverDate'], '%Y-%m-%d') < datetime.today()-timedelta(days=days_back):
                dates_back_found = False
            
        next_dict = response.json()['search-results']['link'][2]
        if next_dict['@ref'] =='next':
            url = next_dict['@href']
        params = {
            'apiKey':api_key,
            'count': 100,  # You can adjust the number of results per page as needed
        }
    df = pd.DataFrame.from_records(out)
    df['source'] = 'Scopus'
    return df
df = get_scopus(2)
df
# Out:
# scopus::::::
# 100
#                  paper_id        date  \
# 0   SCOPUS_ID:85171809400  2023-12-01
# 1   SCOPUS_ID:85171388196  2023-12-01
# 2   SCOPUS_ID:85170350092  2023-12-01
# 3   SCOPUS_ID:85169524858  2023-12-01
# 4   SCOPUS_ID:85169517823  2023-12-01
# ..                    ...         ...
# 95  SCOPUS_ID:85161954005  2023-09-01
# 96  SCOPUS_ID:85160734595  2023-09-01
# 97  SCOPUS_ID:85160300493  2023-09-01
# 98  SCOPUS_ID:85160066399  2023-09-01
# 99  SCOPUS_ID:85158129801  2023-09-01
#
#                                                 title  \
# 0   Cluster analysis driven by unsupervised latent...
# 1   Type, dose, and outcomes of physical therapy i...
# 2   Mitigating underreported error in food frequen...
# 3   North American wintering mallards infected wit...
# 4   Early growth, development and allometry of gly...
# ..                                                ...
# 95  Neural correlates of autobiographical memory r...
# 96  Procedure-Specific Center Volume and Mortality...
# 97  Human Milk Fortification Strategies in the Neo...
# 98                        Benign Colorectal Disorders
# 99  Retrospective analysis of high-intensity focus...
