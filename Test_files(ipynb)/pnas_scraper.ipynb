# %%
import pandas as pd
import requests
from datetime import datetime, timedelta
from bs4 import BeautifulSoup

# %%
def get_pnas_auth_affil_abst(doi):
    authors = []
    affiliations = []
    response = requests.get(f'https://api.crossref.org/works/{doi}')
    json_resp = response.json()
    for id in json_resp['message']['author']:
        name = ""
        for name_type in ['given', 'faimily']:
            try:
                name+=id[name_type]+' '
            except:
                pass
        authors.append(name[:-1])
        for affil in id['affiliation']:
            affiliations.append(affil['name'])
    affiliations = list(set(affiliations))
    authors = list(set(authors))
    try:
        abstract =  BeautifulSoup(json_resp['message']['abstract'], "lxml").text.strip()
    except:
        abstract = ""
    try:
        subjects = json_resp['message']['subject']
    except:
        subjects = ""
    return authors, affiliations,abstract, subjects
def get_pnas_per_school(days_back, affiliation):
    start_date = (datetime.now()-timedelta(days=days_back)).strftime('%Y%m%d')
    end_date = datetime.now().strftime('%Y%m%d')
    url = f'https://www.pnas.org/action/showFeed?ui=0&mi=99mbi3&type=search&feed=rss&query=%2526access%253Don%2526content%253DarticlesChapters%2526dateRange%253D%25255B{start_date}%252BTO%252B{end_date}%25255D%2526field1%253DAffiliation%2526target%253Ddefault%2526text1%253D{affiliation}'

    response = requests.get(url)
    soup = BeautifulSoup(response.text, "xml")
    items = soup.find_all("item")
    out = []
    for item in items:
        paper_info = {}
        paper_info['paper_id'] = item.find("prism:doi").text
        paper_info['title']= item.find("dc:title").text
        paper_info['date']=item.find('prism:coverDisplayDate').text[:10]
        paper_info['url'] = 'https://www.pnas.org/doi/abs/'+paper_info['paper_id']
        paper_info['authors'], paper_info['affiliations'], paper_info['abstract'], paper_info['subjects'] = get_pnas_auth_affil_abst(paper_info['paper_id'])
        out.append(paper_info)
    df = pd.DataFrame.from_records(out)
    df['source'] = 'National Academy of Sciences US'
    return df
def get_pnas_days_back(num_days):
    results = []
    for affil in ['Emory', 'Georgia']:
        results.append(get_pnas_per_school(num_days, affil))
    return pd.concat(results)

# %%
get_pnas_days_back(80)
# Out:
#                     paper_id  \
# 0    10.1073/pnas.2221533120
# 1    10.1073/pnas.2303358120
# 0    10.1073/pnas.2307638120
# 1    10.1073/pnas.2213838120
# 2    10.1073/pnas.2304748120
# 3    10.1073/pnas.2221533120
# 4    10.1073/pnas.2307977120
# 5  10.1093/pnasnexus/pgad268
# 6    10.1073/pnas.2303358120
# 7    10.1073/pnas.2305705120
#
#                                                title        date  \
# 0  Changes in patterns of age-related network con...  2023-08-08
# 1  An interchangeable prion-like domain is requir...  2023-07-25
# 0  Widespread use of proton-pumping rhodopsin in ...  2023-09-26
# 1  Factors Assessing Science’s Self-Presentation ...  2023-09-19
# 2  Exposure to automation explains religious decl...  2023-08-22
# 3  Changes in patterns of age-related network con...  2023-08-08
# 4  Size-dependent charge transfer between water m...  2023-08-01
# 5  Molecular basis for inhibition of methane clat...  2023-08-01
# 6  An interchangeable prion-like domain is requir...  2023-07-25
# 7  Single cobalt atoms anchored on Ti3C2Tx with d...  2023-07-18
#
#                                                  url  \
# 0  https://www.pnas.org/doi/abs/10.1073/pnas.2221...
# 1  https://www.pnas.org/doi/abs/10.1073/pnas.2303...
# 0  https://www.pnas.org/doi/abs/10.1073/pnas.2307...
# 1  https://www.pnas.org/doi/abs/10.1073/pnas.2213...
# 2  https://www.pnas.org/doi/abs/10.1073/pnas.2304...
# 3  https://www.pnas.org/doi/abs/10.1073/pnas.2221...
# 4  https://www.pnas.org/doi/abs/10.1073/pnas.2307...
# 5  https://www.pnas.org/doi/abs/10.1093/pnasnexus...
# 6  https://www.pnas.org/doi/abs/10.1073/pnas.2303...
# 7  https://www.pnas.org/doi/abs/10.1073/pnas.2305...
#
#                                              authors  \
# 0  [, Vince D., Giuseppe, Teresa, Leonardo, Willi...
# 1  [Ricardo C., Emily J., Jeannette V., David J.,...
# 0  [Oscar, Babak, Susumu, Kaylie, Sarah M., Steph...
# 1           [Dror, Yotam, Kathleen Hall, Patrick E.]
# 2  [Kai Chi, Chris G., Joshua Conrad, Pok Man, Adam]
# 3  [, Vince D., Giuseppe, Teresa, Leonardo, Willi...
# 4              [Shiquan, Leo N. Y., Zhong Lin, Zhen]
# 5  [Manlin, James C, Jennifer B, Zixing, Abigail ...
# 6  [Ricardo C., Emily J., Jeannette V., David J.,...
# 7  [Kaida, Yueping, Sihui, Mingmei, Pengfei, Hong...
#
#                                         affiliations  \
# 0  [Lieber Institute for Brain Development, Johns...
# 1  [Department of Biochemistry and Molecular Biol...
# 0  [Atmosphere and Ocean Research Institute, The ...
# 1  [Annenberg Public Policy Center, University of...
# 2  [Department of Management and Organizations, K...
# 3  [Lieber Institute for Brain Development, Johns...
# 4  [School of Materials Science and Engineering, ...
# 5  [School of Civil and Environmental Engineering...
# 6  [Department of Biochemistry and Molecular Biol...
# 7  [Key Laboratory of Poyang Lake Environment and...
#
#                                             abstract             subjects  \
# 0  Alterations in fMRI-based brain functional net...  [Multidisciplinary]
# 1  Retrotransposons and retroviruses shape genome...  [Multidisciplinary]
# 0  Photosynthetic carbon (C) fixation by phytopla...  [Multidisciplinary]
# 1  A confirmatory factor analysis (CFA) of respon...  [Multidisciplinary]
# 2  The global decline of religiosity represents o...  [Multidisciplinary]
# 3  Alterations in fMRI-based brain functional net...  [Multidisciplinary]
# 4  Contact electrification (CE) in water has attr...  [Multidisciplinary]
# 5  Abstract\nMethane clathrates on continental ma...
# 6  Retrotransposons and retroviruses shape genome...  [Multidisciplinary]
# 7  The assimilation of antibiotic resistance gene...  [Multidisciplinary]
#
#                             source
# 0  National Academy of Sciences US
# 1  National Academy of Sciences US
# 0  National Academy of Sciences US
# 1  National Academy of Sciences US
# 2  National Academy of Sciences US
# 3  National Academy of Sciences US
# 4  National Academy of Sciences US
# 5  National Academy of Sciences US
# 6  National Academy of Sciences US
# 7  National Academy of Sciences US

# %%
['paper_id', 'authors', 'subjects', 'title', 'abstract', 'url', 'date', 'affiliations']

# %%
doi = '10.1073/pnas.2307638120'
response = requests.get(f'https://api.crossref.org/works/{doi}')
json_resp = response.json()
json_resp
# Out:
# {'status': 'ok',
#  'message-type': 'work',
#  'message-version': '1.0.0',
#  'message': {'indexed': {'date-parts': [[2023, 9, 22]],
#    'date-time': '2023-09-22T05:06:39Z',
#    'timestamp': 1695359199323},
#   'reference-count': 56,
#   'publisher': 'Proceedings of the National Academy of Sciences',
#   'issue': '39',
#   'license': [{'start': {'date-parts': [[2023, 9, 18]],
#      'date-time': '2023-09-18T00:00:00Z',
#      'timestamp': 1694995200000},
#     'content-version': 'vor',
#     'delay-in-days': 0,
#     'URL': 'https://creativecommons.org/licenses/by-nc-nd/4.0/'}],
#   'funder': [{'DOI': '10.13039/100000001',
#     'name': 'National Science Foundation',
#     'doi-asserted-by': 'publisher',
#     'award': ['OPP1745036']},
#    {'DOI': '10.13039/100000001',
#     'name': 'National Science Foundation',
#     'doi-asserted-by': 'publisher',
#     'award': ['OPP1744760']},
#    {'DOI': '10.13039/100000001',
#     'name': 'National Science Foundation',
#     'doi-asserted-by': 'publisher',
#     'award': ['PLR1440435']}],
#   'content-domain': {'domain': ['www.pnas.org'],
#    'crossmark-restriction': True},
#   'short-container-title': ['Proc. Natl. Acad. Sci. U.S.A.'],
#   'published-print': {'date-parts': [[2023, 9, 26]]},
#   'abstract': '<jats:p>Photosynthetic carbon (C) fixation by phytoplankton in the Southern Ocean (SO) plays a critical role in regulating air–sea exchange of carbon dioxide and thus global climate. In the SO, photosynthesis (PS) is often constrained by low iron, low temperatures, and low but highly variable light intensities. Recently, proton-pumping rhodopsins (PPRs) were identified in marine phytoplankton, providing an alternate iron-free, light-driven source of cellular energy. These proteins pump protons across cellular membranes through light absorption by the chromophore retinal, and the resulting pH energy gradient can then be used for active membrane transport or for synthesis of adenosine triphosphate. Here, we show that PPR is pervasive in Antarctic phytoplankton, especially in iron-limited regions. In a model SO diatom, we found that it was localized to the vacuolar membrane, making the vacuole a putative alternative phototrophic organelle for light-driven production of cellular energy. Unlike photosynthetic C fixation, which decreases substantially at colder temperatures, the proton transport activity of PPR was unaffected by decreasing temperature. Cellular PPR levels in cultured SO diatoms increased with decreasing iron concentrations and energy production from PPR photochemistry could substantially augment that of PS, especially under high light intensities, where PS is often photoinhibited. PPR gene expression and high retinal concentrations in phytoplankton in SO waters support its widespread use in polar environments. PPRs are an important adaptation of SO phytoplankton to growth and survival in their cold, iron-limited, and variable light environment.</jats:p>',
#   'DOI': '10.1073/pnas.2307638120',
#   'type': 'journal-article',
#   'created': {'date-parts': [[2023, 9, 18]],
#    'date-time': '2023-09-18T19:12:07Z',
#    'timestamp': 1695064327000},
#   'update-policy': 'http://dx.doi.org/10.1073/pnas.cm10313',
#   'source': 'Crossref',
#   'is-referenced-by-count': 0,
#   'title': ['Widespread use of proton-pumping rhodopsin in Antarctic phytoplankton'],
#   'prefix': '10.1073',
#   'volume': '120',
#   'author': [{'given': 'Sarah M.',
#     'family': 'Andrew',
#     'sequence': 'first',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]},
#    {'ORCID': 'http://orcid.org/0000-0002-3046-1014',
#     'authenticated-orcid': False,
#     'given': 'Carly M.',
#     'family': 'Moreno',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]},
#    {'ORCID': 'http://orcid.org/0000-0001-6071-0547',
#     'authenticated-orcid': False,
#     'given': 'Kaylie',
#     'family': 'Plumb',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Marine Sciences, University of Georgia, Athens, GA 30602'}]},
#    {'ORCID': 'http://orcid.org/0000-0002-6424-1845',
#     'authenticated-orcid': False,
#     'given': 'Babak',
#     'family': 'Hassanzadeh',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Biological Sciences, University of Southern California, Log Angeles, CA 90089'}]},
#    {'given': 'Laura',
#     'family': 'Gomez-Consarnau',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Biological Sciences, University of Southern California, Log Angeles, CA 90089'},
#      {'name': 'Departamento de Oceanografía Biológica, Centro de Investigación Científca y de Educación Superior de Ensenada, Ensenada, Baja California 22860, Mexico'}]},
#    {'ORCID': 'http://orcid.org/0000-0002-3709-4464',
#     'authenticated-orcid': False,
#     'given': 'Stephanie N.',
#     'family': 'Smith',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]},
#    {'ORCID': 'http://orcid.org/0000-0003-2359-4131',
#     'authenticated-orcid': False,
#     'given': 'Oscar',
#     'family': 'Schofield',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Marine and Coastal Sciences, Rutgers University, New Brunswick, NJ 08901'}]},
#    {'ORCID': 'http://orcid.org/0000-0001-9667-6010',
#     'authenticated-orcid': False,
#     'given': 'Susumu',
#     'family': 'Yoshizawa',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Atmosphere and Ocean Research Institute, The University of Tokyo, Chiba 277-8564, Japan'}]},
#    {'given': 'Takayoshi',
#     'family': 'Fujiwara',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Atmosphere and Ocean Research Institute, The University of Tokyo, Chiba 277-8564, Japan'}]},
#    {'given': 'William G.',
#     'family': 'Sunda',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]},
#    {'given': 'Brian M.',
#     'family': 'Hopkinson',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Marine Sciences, University of Georgia, Athens, GA 30602'}]},
#    {'ORCID': 'http://orcid.org/0000-0002-9309-2930',
#     'authenticated-orcid': False,
#     'given': 'Alecia N.',
#     'family': 'Septer',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]},
#    {'ORCID': 'http://orcid.org/0000-0003-4608-4775',
#     'authenticated-orcid': False,
#     'given': 'Adrian',
#     'family': 'Marchetti',
#     'sequence': 'additional',
#     'affiliation': [{'name': 'Department of Earth, Marine, and Environmental Sciences, University of North Carolina at Chapel Hill, Chapel Hill, NC 27599'}]}],
#   'member': '341',
#   'published-online': {'date-parts': [[2023, 9, 18]]},
#   'reference': [{'key': 'e_1_3_4_1_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/newbio233149a0'},
#    {'key': 'e_1_3_4_2_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1126/science.289.5486.1902'},
#    {'key': 'e_1_3_4_3_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/ismej.2015.74'},
#    {'key': 'e_1_3_4_4_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/ncomms1188'},
#    {'key': 'e_1_3_4_5_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1073/pnas.1118408109'},
#    {'key': 'e_1_3_4_6_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/nature20803'},
#    {'key': 'e_1_3_4_7_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/nrmicro1893'},
#    {'key': 'e_1_3_4_8_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1073/pnas.2133554100'},
#    {'key': 'e_1_3_4_9_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/35081051'},
#    {'key': 'e_1_3_4_10_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1128/mSphere.00525-21'},
#    {'key': 'e_1_3_4_11_2',
#     'doi-asserted-by': 'crossref',
#     'unstructured': 'L. Gómez-Consarnau Microbial rhodopsins are major contributors to the solar energy captured in the sea. Sci. Adv. 5 eaaw8855 (2019). eaaw8855',
#     'DOI': '10.1126/sciadv.aaw8855'},
#    {'key': 'e_1_3_4_12_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1073/pnas.0611035104'},
#    {'key': 'e_1_3_4_13_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1371/journal.pbio.1000359'},
#    {'key': 'e_1_3_4_14_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1007/s00300-017-2228-7'},
#    {'key': 'e_1_3_4_15_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/1758-2229.12948'},
#    {'key': 'e_1_3_4_16_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1071/FP09087'},
#    {'key': 'e_1_3_4_17_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1126/science.1097403'},
#    {'key': 'e_1_3_4_18_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1126/science.abi4355'},
#    {'key': 'e_1_3_4_19_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1046/j.1529-8817.2002.t01-1-01203.x'},
#    {'key': 'e_1_3_4_20_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.4319/lo.1991.36.8.1662'},
#    {'key': 'e_1_3_4_21_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1073/pnas.1810886116'},
#    {'key': 'e_1_3_4_22_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1264/jsme2.ME23015'},
#    {'key': 'e_1_3_4_23_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/s41586-023-05774-6'},
#    {'key': 'e_1_3_4_24_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1093/emboj/cdg183'},
#    {'key': 'e_1_3_4_25_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/gcb.15612'},
#    {'key': 'e_1_3_4_26_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1007/BF00568752'},
#    {'key': 'e_1_3_4_27_2',
#     'first-page': '1063',
#     'article-title': 'Temperature and phytoplankton growth in the sea',
#     'volume': '70',
#     'author': 'Eppley R. W.',
#     'year': '1972',
#     'unstructured': 'R. W. Eppley, Temperature and phytoplankton growth in the sea. Fish. Bull. 70, 1063–1085 (1972).',
#     'journal-title': 'Fish. Bull.'},
#    {'key': 'e_1_3_4_28_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.4319/lo.2012.57.4.1182'},
#    {'key': 'e_1_3_4_29_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1093/bioinformatics/btt607'},
#    {'key': 'e_1_3_4_30_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.1469-8137.1987.tb00122.x'},
#    {'key': 'e_1_3_4_31_2',
#     'doi-asserted-by': 'crossref',
#     'unstructured': 'P. G. Falkowski J. A. Raven Aquatic Photosynthesis (Second Edition) (Princeton University Press ed. STU–Student edition 2007).',
#     'DOI': '10.1515/9781400849727'},
#    {'key': 'e_1_3_4_32_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.bbabio.2008.03.013'},
#    {'key': 'e_1_3_4_33_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/S0005-2736(00)00130-9'},
#    {'key': 'e_1_3_4_34_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.1469-8137.1988.tb04196.x'},
#    {'key': 'e_1_3_4_35_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/2161178a0'},
#    {'key': 'e_1_3_4_36_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1126/science.289.5480.739'},
#    {'key': 'e_1_3_4_37_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.3389/fmars.2019.00167'},
#    {'key': 'e_1_3_4_38_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1002/lno.11562'},
#    {'key': 'e_1_3_4_39_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.4319/lo.2000.45.7.1501'},
#    {'key': 'e_1_3_4_40_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1146/annurev.arplant.50.1.333'},
#    {'key': 'e_1_3_4_41_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.marchem.2017.06.004'},
#    {'key': 'e_1_3_4_42_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1038/ismej.2014.171'},
#    {'key': 'e_1_3_4_43_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1002/lno.11404'},
#    {'key': 'e_1_3_4_44_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1073/pnas.2211018119'},
#    {'key': 'e_1_3_4_45_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.1529-8817.2008.00518.x'},
#    {'key': 'e_1_3_4_46_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1080/01965581.1988.10749544'},
#    {'key': 'e_1_3_4_47_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1093/plankt/3.2.193'},
#    {'key': 'e_1_3_4_48_2',
#     'unstructured': 'M. Y. Gorbunov P. Falkowski “Fluorescence Induction and Relaxation (FIRe) technique and instrumentation for monitoring photosynthetic processes and primary production in aquatic ecosystems” in Proceedings of 13th International Congress of Photosynthesis A. van der Est D. Bruce Eds. (Allen Press Montreal 2005) pp. 1029–1031.'},
#    {'key': 'e_1_3_4_49_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1111/j.0022-3646.1992.00304.x'},
#    {'key': 'e_1_3_4_50_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1146/annurev.bi.51.070182.003103'},
#    {'key': 'e_1_3_4_51_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1146/annurev.pc.41.100190.003343'},
#    {'key': 'e_1_3_4_52_2',
#     'doi-asserted-by': 'crossref',
#     'unstructured': 'H. Ducklow “The marine system of the Western Antarctic Peninsula” in Antarctic Ecosystems A. D. Rogers N. M. Johnston E. J. Murphy A. Clarke Eds. (Blackwell Publishing Ltd. 2012) 10.1002/9781444347241.ch5 pp. 121–159.',
#     'DOI': '10.1002/9781444347241.ch5'},
#    {'key': 'e_1_3_4_53_2',
#     'doi-asserted-by': 'publisher',
#     'DOI': '10.1016/j.dsr.2015.02.009'},
#    {'key': 'e_1_3_4_54_2',
#     'volume-title': 'A manual of chemical and biological methods for seawater analysis',
#     'author': 'Parsons T. R.',
#     'year': '1984',
#     'unstructured': 'T. R. Parsons, Y. Maita, C. M. Lalli, A manual of chemical and biological methods for seawater analysis (Pergamon Press, Oxford, 1984).'},
#    {'key': 'e_1_3_4_55_2',
#     'doi-asserted-by': 'crossref',
#     'unstructured': 'C. M. Moreno Molecular physiology of Antarctic diatom natural assemblages reveals multiple strategies contributing to their ecological success. bioRxiv [Preprint] (2023). https://doi.org/10.1101/2023.04.19.537459 (Accessed 20 April 2023).',
#     'DOI': '10.1101/2023.04.19.537459'},
#    {'key': 'e_1_3_4_56_2',
#     'unstructured': 'C. M. Moreno A. Marchetti Metatranscriptomics of phytoplankton communities from the Western Antarctic Peninsula. Sequence Read Archive. https://www.ncbi.nlm.nih.gov/sra/?term=PRJNA877830. Accessed 8 September 2022.'}],
#   'container-title': ['Proceedings of the National Academy of Sciences'],
#   'original-title': [],
#   'language': 'en',
#   'link': [{'URL': 'https://pnas.org/doi/pdf/10.1073/pnas.2307638120',
#     'content-type': 'unspecified',
#     'content-version': 'vor',
#     'intended-application': 'similarity-checking'}],
#   'deposited': {'date-parts': [[2023, 9, 21]],
#    'date-time': '2023-09-21T13:34:16Z',
#    'timestamp': 1695303256000},
#   'score': 1,
#   'resource': {'primary': {'URL': 'https://pnas.org/doi/10.1073/pnas.2307638120'}},
#   'subtitle': [],
#   'short-title': [],
#   'issued': {'date-parts': [[2023, 9, 18]]},
#   'references-count': 56,
#   'journal-issue': {'issue': '39',
#    'published-print': {'date-parts': [[2023, 9, 26]]}},
#   'alternative-id': ['10.1073/pnas.2307638120'],
#   'URL': 'http://dx.doi.org/10.1073/pnas.2307638120',
#   'relation': {},
#   'ISSN': ['0027-8424', '1091-6490'],
#   'issn-type': [{'value': '0027-8424', 'type': 'print'},
#    {'value': '1091-6490', 'type': 'electronic'}],
#   'subject': ['Multidisciplinary'],
#   'published': {'date-parts': [[2023, 9, 18]]},
#   'assertion': [{'value': '2023-05-06',
#     'order': 0,
#     'name': 'received',
#     'label': 'Received',
#     'group': {'name': 'publication_history', 'label': 'Publication History'}},
#    {'value': '2023-08-13',
#     'order': 1,
#     'name': 'accepted',
#     'label': 'Accepted',
#     'group': {'name': 'publication_history', 'label': 'Publication History'}},
#    {'value': '2023-09-18',
#     'order': 2,
#     'name': 'published',
#     'label': 'Published',
#     'group': {'name': 'publication_history',
#      'label': 'Publication History'}}]}}

# %%
# Out:
# 'Photosynthetic carbon (C) fixation by phytoplankton in the Southern Ocean (SO) plays a critical role in regulating air–sea exchange of carbon dioxide and thus global climate. In the SO, photosynthesis (PS) is often constrained by low iron, low temperatures, and low but highly variable light intensities. Recently, proton-pumping rhodopsins (PPRs) were identified in marine phytoplankton, providing an alternate iron-free, light-driven source of cellular energy. These proteins pump protons across cellular membranes through light absorption by the chromophore retinal, and the resulting pH energy gradient can then be used for active membrane transport or for synthesis of adenosine triphosphate. Here, we show that PPR is pervasive in Antarctic phytoplankton, especially in iron-limited regions. In a model SO diatom, we found that it was localized to the vacuolar membrane, making the vacuole a putative alternative phototrophic organelle for light-driven production of cellular energy. Unlike photosynthetic C fixation, which decreases substantially at colder temperatures, the proton transport activity of PPR was unaffected by decreasing temperature. Cellular PPR levels in cultured SO diatoms increased with decreasing iron concentrations and energy production from PPR photochemistry could substantially augment that of PS, especially under high light intensities, where PS is often photoinhibited. PPR gene expression and high retinal concentrations in phytoplankton in SO waters support its widespread use in polar environments. PPRs are an important adaptation of SO phytoplankton to growth and survival in their cold, iron-limited, and variable light environment.'

# %%
def get_pnas_auth_affil_abst(doi):
    authors = []
    affiliations = []
    response = requests.get(f'https://api.crossref.org/works/{doi}')
    json_resp = response.json()
    for id in json_resp['message']['author']:
        authors.append(id['given']+' '+id['family'])
        for affil in id['affiliation']:
            affiliations.append(affil['name'])
    affiliations = list(set(affiliations))
    authors = list(set(authors))
    return authors, affiliations, json_resp['message']['abstract'][8:][:-9],
