# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# %%
nature_api_key = 'f7423b1e5e5cf7154a90dfecbaa9a66b'

# %%
url = 'https://www.biorxiv.org/search/jcode%3Abiorxiv%7C%7Cmedrxiv%20limit_from%3A2023-09-26%20limit_to%3A2023-09-28%20numresults%3A10000%20sort%3Apublication-date%20direction%3Adescending%20format_result%3Astandard'
response = requests.get(url)

# %%
soup = BeautifulSoup(response.text, 'html.parser')
soup.text
# Out:
# '\n\n\n\n\n\n\n\n\n\n\n\n\nSearch Results | bioRxiv\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nSkip to main content\n\n\n\n\n\n\n\n\n \n\n\n\n\n\n\n\nHome\nAbout\nSubmit\nALERTS / RSS\n \n\n\n\n\n\n\n\n\n\nSearch for this keyword \n\n\n\n\n \n\n\n\nAdvanced Search \n\n\n\n\n\n\n \n \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\t629 Results\n \n\n\n\nfor published between "26 Sep, 2023  and  28 Sep, 2023"\n \n\n\n\n\n \n\n\n\n\n\n\n\n\nItems/Page \n10255075\n\n\nOrder by \nBest MatchOldest FirstNewest First\n\n\n\n \n\n\n\n\nSearch Terms & Keywords \n\nType a term to search within all articles in this journal: e.g., stem cell\n\nLimit ResultsDate of Publication\nFrom \n\nDate \n\n e.g., 2023-09-28\n\n\n\n — \nThrough \n\nDate \n\n e.g., 2023-09-28\n\n\n\n\nInclude articles in bioRxiv and/or medRxiv: \nbioRxivbioRxiv and medRxivmedRxiv\n\n\nInclude articles in subject area(s) \n-- All Collections --Animal Behavior and CognitionBiochemistryBioengineeringBioinformaticsBiop
# ...

# %%
num_read = 10
response = requests.get(f'https://api.biorxiv.org/details/biorxiv/2023-08-21/2023-08-28/{num_read}')

# %%
response.json()
# Out:
# {'messages': [{'status': 'ok',
#    'interval': '2023-08-21:2023-08-28',
#    'cursor': '10',
#    'count': 100,
#    'count_new_papers': 947,
#    'total': 1299}],
#  'collection': [{'doi': '10.1101/2020.05.26.104687',
#    'title': 'Pictorial balance is a bottom-up aesthetic property mediated by eye movements. A model of a primitive visual operating system explains balance and visual properties of pictures',
#    'authors': 'Corwin, D. M.',
#    'author_corresponding': 'David M Corwin',
#    'author_corresponding_institution': 'David Corwin MD',
#    'date': '2023-08-22',
#    'version': '18',
#    'type': 'new results',
#    'license': 'cc_by',
#    'category': 'neuroscience',
#    'jatsxml': 'https://www.biorxiv.org/content/early/2023/08/22/2020.05.26.104687.source.xml',
# ...
